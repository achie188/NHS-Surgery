# %%
NDays = 5
# %store NDays

Criteria_types = ['CLINICAL URGENCY', 'CLINICAL EFFICIENCY', 'WAITING URGENCY', 
                   'WAITING EFFICIENCY', 'WELFARE URGENCY', 'WELFARE EFFICIENCY', 'VOLUME']

# %run ./Patient_waiting_list_analysis.ipynb
# Out:
# Stored 'NDays' (int)
# WAITING LIST SUMMARY
# Total number of patients: 1,180
#
# Total clinical urgency:   25,033
# Total waiting time:       331,028
# Total welfare cost:       7,076,020
#
# Average clinical urgency: 21.21
# Average waiting time:     280.53
# Average welfare cost:     5,997.0
#
# Highest Urgency:          50
# Longest Waiting Time:     376
# Highest Welfare Cost:     14,360
# --------------
# Stored 'Clinical_urgency' (int)
# Stored 'Clinical_efficiency' (int)
# Stored 'Waiting_urgency' (int)
# Stored 'Waiting_efficiency' (int)
# Stored 'Welfare_urgency' (int)
# Stored 'Welfare_efficiency' (int)
# Stored 'Volume' (int)

# %%
# %run ./Patient_list_builder.ipynb

for Crit_Type in Criteria_types:
    
    # %store Crit_Type
    # %run ./Theatre_schedule_organiser.ipynb
# Out:
# Stored 'Crit_Type' (str)
#
# If you schedule patients by CLINICAL URGENCY over next 5 days
# Patients scheduled:    307.0
#   - Clinical urgency:  Total - 7,853.0      Avg - 25.6
#   - Waiting time:      Total - 84,837.0    Avg - 276.0
#   - Welfare cost:      Total - 2,186,445.0  Avg - 7,122.0
#
# Waiting list after:
# Patients:              873.0
#   - Clinical urgency:  Total - 17,180.0     Avg - 19.7
#   - Waiting time:      Total - 246,191.0    Avg - 282.0
#   - Welfare cost:      Total - 4,889,575.0  Avg - 5,997.0
#
# Theatre efficiency - 74.3%
# --------------
#
# Stored 'Clinical_urgency' (int)
# Stored 'Crit_Type' (str)
#
# If you schedule patients by CLINICAL EFFICIENCY over next 5 days
# Patients scheduled:    396.0
#   - Clinical urgency:  Total - 8,947.0      Avg - 22.6
#   - Waiting time:      Total - 110,261.0    Avg - 278.0
#   - Welfare cost:      Total - 2,492,060.0  Avg - 6,293.0
#
# Waiting list after:
# Patients:              784.0
#   - Clinical urgency:  Total - 16,086.0     Avg - 20.5
#   - Waiting time:      Total - 220,767.0    Avg - 282.0
#   - Welfare cost:      Total - 4,583,960.0  Avg - 5,997.0
#
# Theatre efficiency - 67.2%
# --------------
#
# Stored 'Clinical_efficiency' (int)
# Stored 'Crit_Type' (str)
#
# If you schedule patients by WAITING URGENCY over next 5 days
# Patients scheduled:    319.0
#   - Clinical urgency:  Total - 6,809.0      Avg - 21.3
#   - Waiting time:      Total - 104,221.0    Avg - 327.0
#   - Welfare cost:      Total - 2,236,822.0  Avg - 7,012.0
#
# Waiting list after:
# Patients:              861.0
#   - Clinical urgency:  Total - 18,224.0     Avg - 21.2
#   - Waiting time:      Total - 226,807.0    Avg - 263.0
#   - Welfare cost:      Total - 4,839,198.0  Avg - 5,997.0
#
# Theatre efficiency - 75.1%
# --------------
#
# Stored 'Waiting_urgency' (int)
# Stored 'Crit_Type' (str)
#
# If you schedule patients by WAITING EFFICIENCY over next 5 days
# Patients scheduled:    402.0
#   - Clinical urgency:  Total - 8,326.0      Avg - 20.7
#   - Waiting time:      Total - 125,464.0    Avg - 312.0
#   - Welfare cost:      Total - 2,609,022.0  Avg - 6,490.0
#
# Waiting list after:
# Patients:              778.0
#   - Clinical urgency:  Total - 16,707.0     Avg - 21.5
#   - Waiting time:      Total - 205,564.0    Avg - 264.0
#   - Welfare cost:      Total - 4,466,998.0  Avg - 5,997.0
#
# Theatre efficiency - 67.0%
# --------------
#
# Stored 'Waiting_efficiency' (int)
# Stored 'Crit_Type' (str)
#
# If you schedule patients by WELFARE URGENCY over next 5 days
# Patients scheduled:    309.0
#   - Clinical urgency:  Total - 7,540.0      Avg - 24.4
#   - Waiting time:      Total - 98,723.0    Avg - 319.0
#   - Welfare cost:      Total - 2,411,537.0  Avg - 7,804.0
#
# Waiting list after:
# Patients:              871.0
#   - Clinical urgency:  Total - 17,493.0     Avg - 20.1
#   - Waiting time:      Total - 232,305.0    Avg - 267.0
#   - Welfare cost:      Total - 4,664,483.0  Avg - 5,997.0
#
# Theatre efficiency - 75.1%
# --------------
#
# Stored 'Welfare_urgency' (int)
# Stored 'Crit_Type' (str)
#
# If you schedule patients by WELFARE EFFICIENCY over next 5 days
# Patients scheduled:    391.0
#   - Clinical urgency:  Total - 8,781.0      Avg - 22.5
#   - Waiting time:      Total - 121,753.0    Avg - 311.0
#   - Welfare cost:      Total - 2,732,979.0  Avg - 6,990.0
#
# Waiting list after:
# Patients:              789.0
#   - Clinical urgency:  Total - 16,252.0     Avg - 20.6
#   - Waiting time:      Total - 209,275.0    Avg - 265.0
#   - Welfare cost:      Total - 4,343,041.0  Avg - 5,997.0
#
# Theatre efficiency - 68.4%
# --------------
#
# Stored 'Welfare_efficiency' (int)
# Stored 'Crit_Type' (str)
#
# If you schedule patients by VOLUME over next 5 days
# Patients scheduled:    399.0
#   - Clinical urgency:  Total - 8,249.0      Avg - 20.7
#   - Waiting time:      Total - 112,012.0    Avg - 281.0
#   - Welfare cost:      Total - 2,324,798.0  Avg - 5,827.0
#
# Waiting list after:
# Patients:              781.0
#   - Clinical urgency:  Total - 16,784.0     Avg - 21.5
#   - Waiting time:      Total - 219,016.0    Avg - 280.0
#   - Welfare cost:      Total - 4,751,222.0  Avg - 5,997.0
#
# Theatre efficiency - 64.2%
# --------------
#
# Stored 'Volume' (int)

# %%
url = r'C:\Users\achie\Github\NHS-Surgery\V2\Summary.xlsx'
Overall_Efficiency_Summary = pd.read_excel(url, sheet_name = 6, header=0, index_col=0)

Overall_Efficiency_Summary
# Out:
#                          CLINICAL URGENCY CLINICAL EFFICIENCY WAITING URGENCY  \
# Number of Operations                  307                 396             319
# Total Clinical Urgency            7,853.0             8,947.0         6,809.0
# Average Clinical Urgency             25.6                22.6            21.3
# Total Waiting Time               84,837.0           110,261.0       104,221.0
# Average Waiting Time                276.0               278.0           327.0
# Total Welfare Cost            2,186,445.0         2,492,060.0     2,236,822.0
# Average Welfare Cost              7,122.0             6,293.0         7,012.0
# Theatre Efficiency                  74.3%               67.2%           75.1%
#
#                          WAITING EFFICIENCY WELFARE URGENCY  \
# Number of Operations                    402             309
# Total Clinical Urgency              8,326.0         7,540.0
# Average Clinical Urgency               20.7            24.4
# Total Waiting Time                125,464.0        98,723.0
# Average Waiting Time                  312.0           319.0
# Total Welfare Cost              2,609,022.0     2,411,537.0
# Average Welfare Cost                6,490.0         7,804.0
# Theatre Efficiency                    67.0%           75.1%
#
#                          WELFARE EFFICIENCY       VOLUME
# Number of Operations                    391          399
# Total Clinical Urgency              8,781.0      8,249.0
# Average Clinical Urgency               22.5         20.7
# Total Waiting Time                121,753.0    112,012.0
# Average Waiting Time                  311.0        281.0
# Total Welfare Cost              2,732,979.0  2,324,798.0
# Average Welfare Cost                6,990.0      5,827.0
# Theatre Efficiency                    68.4%        64.2%
